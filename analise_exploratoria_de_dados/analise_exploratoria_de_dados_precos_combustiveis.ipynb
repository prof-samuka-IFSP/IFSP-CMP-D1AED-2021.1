# %% [markdown]
# **D1DAE: Análise Estatística para Ciência de Dados (2021.1)** <br/>
# IFSP Campinas
#
# Profs: Ricardo Sovat, Samuel Martins <br/><br/>
#
# <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png" /></a><br />This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>.

# %% [markdown]
# ### Pacotes usados neste Notebook

# %%
# pacotes usados neste notebook
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <h1>Análise Exploratória de Dados</h1><hr/>

# %% [markdown]
# A **Análise Exploratória de Dados** refere-se ao processo de investigação de dados (de um problema) para a descoberta de _insights_, padrões, anomalias, testar hipóteses e checar suposições com a ajuda de técnicas e conceitos estatísticos e representações visuais/gráficas.

# %% [markdown]
# <h2>1. Dataset</h2>
# <hr/>

# %% [markdown]
# **Dataset**: Gas Prices in Brazil: https://www.kaggle.com/matheusfreitag/gas-prices-in-brazil <br/>
#
# Este dataset contém os **registros dos preços médios semanais dos combustíveis do Brasil entre os anos de 2004 e 2019**. <br/>
# Cada *observação (registro/linha)* consiste em um registro de preço aferido para um dado tipo de combustível em uma dada localidade do Brasil. <br/>
# Alguns dos principais *atributos* (colunas) do dataset são: 'ESTADO', 'PRODUTO', 'NÚMERO DE POSTOS PESQUISADOS', 'PREÇO MÉDIO REVENDA'.

# %% [markdown]
# O dataset utilizado neste notebook já foi _pré-processado_ anteriormente. Para mais informações, cheque os vídeos mostrados do curso ["Pandas Essencial" no YouTube](https://www.youtube.com/playlist?list=PL3ZslI15yo2pfkf7EGNR14xTwe-wZ2bNX), onde realizamos tal preprocessamento.

# %% [markdown]
# ### 1.1. Importando o Dataset

# %%
data = pd.read_csv("./datasets/GasPricesinBrazil_2004-2019_preprocessado_final.csv")

# %%
data
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 103387   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 103388   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 103389   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 103390   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 103391   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %% [markdown]
# ### 1.2. Informações básicas do Dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103392 entries, 0 to 103391
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   103392 non-null  object
#  1   DATA FINAL                     103392 non-null  object
#  2   REGIÃO                         103392 non-null  object
#  3   ESTADO                         103392 non-null  object
#  4   PRODUTO                        103392 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   103392 non-null  int64
#  6   UNIDADE DE MEDIDA              103392 non-null  object
#  7   PREÇO MÉDIO REVENDA            103392 non-null  float64
#  8   DESVIO PADRÃO REVENDA          103392 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           103392 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           103392 non-null  float64
#  11  MARGEM MÉDIA REVENDA           103392 non-null  float64
# ...

# %% [markdown]
# <br/>
#
# O dataset possui **103392** registros/observações/linhas e **20** atributos/variáveis/colunas.
# Não há nenhum valor null nas colunas (uma checagem mais rigorosa foi feita no curso ["Pandas Essencial"](https://www.youtube.com/playlist?list=PL3ZslI15yo2pfkf7EGNR14xTwe-wZ2bNX)).

# %% [markdown]
# <h2>2. Análise Exploratória de Dados</h2>
# <hr/>

# %% [markdown]
# ### 2.1 Como os preços da Gasolina Comum em São Paulo variaram em 2018?

# %%
df = data.query('ESTADO == "SAO PAULO" and ANO == 2018 and PRODUTO == "GASOLINA COMUM"').reset_index(drop=True)

# %%
df.head()
# Out:
#   DATA INICIAL  DATA FINAL   REGIÃO     ESTADO         PRODUTO  \
# 0   2018-01-07  2018-01-13  SUDESTE  SAO PAULO  GASOLINA COMUM
# 1   2018-01-14  2018-01-20  SUDESTE  SAO PAULO  GASOLINA COMUM
# 2   2018-01-21  2018-01-27  SUDESTE  SAO PAULO  GASOLINA COMUM
# 3   2018-01-28  2018-02-03  SUDESTE  SAO PAULO  GASOLINA COMUM
# 4   2018-02-04  2018-02-10  SUDESTE  SAO PAULO  GASOLINA COMUM
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                          1641              R$/l                3.988
# 1                          1648              R$/l                4.002
# 2                          1648              R$/l                4.006
# 3                          1644              R$/l                4.019
# 4                          1646              R$/l                4.004
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                  0.156                 3.499                 4.599
# ...

# %% [markdown]
# #### **Estatísticas Descritivas**

# %%
df.describe()
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                     52.000000            52.000000
# mean                    1610.211538             4.202769
# std                      213.627432             0.180672
# min                      102.000000             3.970000
# 25%                     1639.000000             4.008000
# 50%                     1642.000000             4.202000
# 75%                     1644.000000             4.336250
# max                     1649.000000             4.512000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count              52.000000             52.000000             52.000000
# mean                0.175500              3.671500              4.975750
# std                 0.017955              0.163808              0.211198
# min                 0.150000              3.369000              4.499000
# 25%                 0.159750              3.499000              4.899000
# ...

# %%
df['PREÇO MÉDIO REVENDA'].describe()
# Out:
# count    52.000000
# mean      4.202769
# std       0.180672
# min       3.970000
# 25%       4.008000
# 50%       4.202000
# 75%       4.336250
# max       4.512000
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
df['PREÇO MÉDIO REVENDA'].describe().to_frame()
# Out:
#        PREÇO MÉDIO REVENDA
# count            52.000000
# mean              4.202769
# std               0.180672
# min               3.970000
# 25%               4.008000
# 50%               4.202000
# 75%               4.336250
# max               4.512000

# %% [markdown]
# #### **Tendência Central dos Preços**

# %%
print(f'O preço médio da Gasolina no Estado de São em 2018 foi de R$ {df["PREÇO MÉDIO REVENDA"].mean():.2f} ± {df["PREÇO MÉDIO REVENDA"].std():.2f}')
# Out:
# O preço médio da Gasolina no Estado de São em 2018 foi de R$ 4.20 ± 0.18

# %%
plt.figure(figsize=(6,6))
ax = sns.barplot(y='PREÇO MÉDIO REVENDA', ci='sd', data=df)
ax.set_title('Gasolina Comum no Estado de SP em 2018')
ax.set_ylabel('Preço Médio (R$)')
# Out:
# Text(0, 0.5, 'Preço Médio (R$)')

# %%
# "Truque" para colocar o valor da variável em cima da barra
plt.figure(figsize=(6,6))
ax = sns.barplot(y='PREÇO MÉDIO REVENDA', ci='sd', data=df)
ax.set_title('Gasolina Comum no Estado de SP em 2018')
ax.set_ylabel('Preço Médio (R$)')

for bar in ax.patches:
    height = bar.get_height()  # equivalent to counting
    x = bar.get_x() + bar.get_width()
    y = height
    ax.annotate(f'R$ {height:.2f}',
                xy=(x, y),
                xytext=(0, 3),  # 3 points vertical offset
                textcoords="offset points",
                ha='center', va='bottom')

# %%
print(f'A mediana do preço da Gasolina Comum no estado de SP em 2018 é R$ {df["PREÇO MÉDIO REVENDA"].median():.2f}')
# Out:
# A mediana do preço da Gasolina Comum no estado de SP em 2018 é R$ 4.20

# %% [markdown]
# ### **Variabilidade**

# %% [markdown]
# #### Histograma com número de bins padrão:

# %%
plt.figure(figsize=(10, 6))
ax = sns.histplot(x='PREÇO MÉDIO REVENDA', data=df)
ax.set_title('Histograma dos Preços da Gasolina do Estado de SP em 2018')
ax.set_xlabel('Preço da Gasolina (R$)')
ax.set_ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %%
# alterando o número de ticks
plt.figure(figsize=(10, 6))
ax = sns.histplot(x='PREÇO MÉDIO REVENDA', data=df)
ax.set_title('Histograma dos Preços da Gasolina do Estado de SP em 2018')
ax.set_xlabel('Preço da Gasolina (R$)')
ax.set_ylabel('Frequência')
ax.set_xticks(np.arange(4, 4.6, 0.1))

# %% [markdown]
# #### Alterando o **número de bins** do Histograma.

# %%
plt.figure(figsize=(10, 6))
ax = sns.histplot(x='PREÇO MÉDIO REVENDA', data=df, bins=10)
ax.set_title('Histograma dos Preços da Gasolina do Estado de SP em 2018')
ax.set_xlabel('Preço da Gasolina (R$)')
ax.set_ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %% [markdown]
# #### Checando a variabilidade usando **BoxPlots**

# %%
# checando a variabidade da distribuição dos preços médios de revenda do estado de SP em 2018
plt.figure(figsize=(10, 6))
ax = sns.boxplot(x='PREÇO MÉDIO REVENDA', data=df)
ax.set_title('Gasolina Comum no Estado de SP em 2018')
ax.set_xlabel('Preço da Gasolina (R$)')
# Out:
# Text(0.5, 0, 'Preço da Gasolina (R$)')

# %% [markdown]
# #### Checando a variabilidade usando **Violin Plot**

# %%
plt.figure(figsize=(10, 6))
ax = sns.violinplot(x='PREÇO MÉDIO REVENDA', data=df)
ax.set_title('Gasolina Comum no Estado de SP em 2018')
ax.set_xlabel('Preço da Gasolina (R$)')
# Out:
# Text(0.5, 0, 'Preço da Gasolina (R$)')

# %% [markdown]
# ### 2.2 Como os preços da Gasolina Comum e do Etanol em São Paulo variaram em 2018?

# %%
df = data.query('ESTADO == "SAO PAULO" and ANO == 2018 and PRODUTO in ["GASOLINA COMUM", "ETANOL HIDRATADO"]').reset_index(drop=True)

# %%
df.head()
# Out:
#   DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0   2018-01-07  2018-01-13  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1   2018-01-07  2018-01-13  SUDESTE  SAO PAULO    GASOLINA COMUM
# 2   2018-01-14  2018-01-20  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3   2018-01-14  2018-01-20  SUDESTE  SAO PAULO    GASOLINA COMUM
# 4   2018-01-21  2018-01-27  SUDESTE  SAO PAULO  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                          1664              R$/l                2.833
# 1                          1641              R$/l                3.988
# 2                          1661              R$/l                2.868
# 3                          1648              R$/l                4.002
# 4                          1662              R$/l                2.874
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                  0.139                 2.449                 3.399
# ...

# %% [markdown]
# #### Computando as estatísticas descritivas

# %%
stats = df.groupby('PRODUTO')['PREÇO MÉDIO REVENDA'].describe()
stats
# Out:
#                   count      mean       std    min     25%    50%      75%  \
# PRODUTO
# ETANOL HIDRATADO   52.0  2.711904  0.141365  2.393  2.6315  2.720  2.83825
# GASOLINA COMUM     52.0  4.202769  0.180672  3.970  4.0080  4.202  4.33625
#
#                     max
# PRODUTO
# ETANOL HIDRATADO  2.892
# GASOLINA COMUM    4.512

# %%
print(f'O preço médio do Etanol no Estado de SP em 2018 é de R$ {stats.loc["ETANOL HIDRATADO", "mean"]:.2f} ± {stats.loc["ETANOL HIDRATADO", "std"]:.2f}')
print(f'O preço médio da Gasolina Comum no Estado de SP em 2018 é de R$ {stats.loc["GASOLINA COMUM", "mean"]:.2f} ± {stats.loc["GASOLINA COMUM", "std"]:.2f}')
# Out:
# O preço médio do Etanol no Estado de SP em 2018 é de R$ 2.71 ± 0.14
# O preço médio da Gasolina Comum no Estado de SP em 2018 é de R$ 4.20 ± 0.18

# %%
print(f'A mediana do preço do Etanol no Estado de SP em 2018 é de R$ {stats.loc["ETANOL HIDRATADO", "50%"]:.2f}')
print(f'A mediana do preço da Gasolina Comum no Estado de SP em 2018 é de R$ {stats.loc["GASOLINA COMUM", "50%"]:.2f}')
# Out:
# A mediana do preço do Etanol no Estado de SP em 2018 é de R$ 2.72
# A mediana do preço da Gasolina Comum no Estado de SP em 2018 é de R$ 4.20

# %% [markdown]
# #### Gráfico de Barras

# %%
plt.figure(figsize=(10, 6))
ax = sns.barplot(x="PRODUTO", y='PREÇO MÉDIO REVENDA', ci='sd', data=df)
ax.set_title('Gasolina Comum x Etanol no Estado de SP em 2018')
ax.set_ylabel('Preço Médio (R$)')
# Out:
# Text(0, 0.5, 'Preço Médio (R$)')

# %%
plt.figure(figsize=(10, 6))
ax = sns.barplot(x="PRODUTO", y='PREÇO MÉDIO REVENDA', ci='sd', data=df)
ax.set_title('Gasolina Comum x Etanol no Estado de SP em 2018')
ax.set_ylabel('Preço Médio (R$)')

for bar in ax.patches:
    height = bar.get_height()  # equivalent to counting
    x = bar.get_x() + bar.get_width()
    y = height
    ax.annotate(f'R$ {height:.2f}',
                xy=(x, y),
                xytext=(0, 3),  # 3 points vertical offset
                textcoords="offset points",
                ha='center', va='bottom')

# %% [markdown]
# #### Histogramas

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df.query('PRODUTO == "ETANOL HIDRATADO"'), x="PREÇO MÉDIO REVENDA", kde=True, color="skyblue")
sns.histplot(data=df.query('PRODUTO == "GASOLINA COMUM"'), x="PREÇO MÉDIO REVENDA", kde=True, color="gold")
# Out:
# <AxesSubplot:xlabel='PREÇO MÉDIO REVENDA', ylabel='Count'>

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 6))
sns.histplot(data=df.query('PRODUTO == "ETANOL HIDRATADO"'), x="PREÇO MÉDIO REVENDA", kde=True, color="skyblue", ax=axs[0])
sns.histplot(data=df.query('PRODUTO == "GASOLINA COMUM"'), x="PREÇO MÉDIO REVENDA", kde=True, color="gold", ax=axs[1])
# Out:
# <AxesSubplot:xlabel='PREÇO MÉDIO REVENDA', ylabel='Count'>

# %% [markdown]
# #### BoxPlot

# %%
plt.figure(figsize=(10, 6))
ax = sns.boxplot(data=df, x='PRODUTO', y='PREÇO MÉDIO REVENDA')
ax.set_title('Gasolina Comum x Etanol no Estado de SP em 2018')
ax.set_xlabel('Produto')
ax.set_ylabel('Preço Médio (R$)')
# Out:
# Text(0, 0.5, 'Preço Médio (R$)')

# %% [markdown]
# #### Violin Plot

# %%
plt.figure(figsize=(10, 6))
ax = sns.violinplot(data=df, x='PRODUTO', y='PREÇO MÉDIO REVENDA')
ax.set_title('Gasolina Comum x Etanol no Estado de SP em 2018')
ax.set_xlabel('Produto')
ax.set_ylabel('Preço Médio (R$)')
ax.set_yticks(np.arange(2.0, 5.01, 0.1))

# %% [markdown]
# ### 2.3 Como os preços da Gasolina Comum e Etanol variaram no estado de SP ao longo dos anos?

# %%
df = data.query('ESTADO == "SAO PAULO" and PRODUTO in ["ETANOL HIDRATADO", "GASOLINA COMUM"]').reset_index(drop=True)

# %%
df.groupby(by=["ANO", "PRODUTO"])["PREÇO MÉDIO REVENDA"].describe()
# Out:
#                        count      mean       std    min      25%     50%  \
# ANO  PRODUTO
# 2004 ETANOL HIDRATADO   34.0  1.049059  0.157977  0.766  0.90475  1.0325
#      GASOLINA COMUM     34.0  2.047294  0.087135  1.888  2.03000  2.0340
# 2005 ETANOL HIDRATADO   50.0  1.182500  0.112241  0.978  1.07075  1.2170
#      GASOLINA COMUM     50.0  2.232900  0.087034  2.144  2.16175  2.1910
# 2006 ETANOL HIDRATADO   53.0  1.419623  0.189749  1.211  1.25800  1.3550
#      GASOLINA COMUM     53.0  2.442585  0.030641  2.383  2.42100  2.4450
# 2007 ETANOL HIDRATADO   52.0  1.272212  0.146878  1.063  1.11225  1.2960
#      GASOLINA COMUM     52.0  2.413865  0.024343  2.376  2.39275  2.4165
# 2008 ETANOL HIDRATADO   52.0  1.273769  0.028608  1.228  1.24875  1.2700
#      GASOLINA COMUM     52.0  2.402788  0.006393  2.393  2.39700  2.4020
# 2009 ETANOL HIDRATADO   50.0  1.329040  0.144401  1.134  1.22375  1.3000
#      GASOLINA COMUM     50.0  2.403000  0.027974  2.353  2.38100  2.4020
# ...

# %% [markdown]
# #### Lineplot

# %%
ticks_precos = np.arange(0.0, 5.01, 0.25)

plt.figure(figsize=(20, 12))
ax = sns.lineplot(data=df, x="ANO", y="PREÇO MÉDIO REVENDA", hue="PRODUTO", ci='sd')
ax.set_title('Gasolina Comum x Etanol no Estado de SP entre 2004 e 2018')
ax.set_yticks(ticks_precos)
plt.grid()

# From documentation: https://seaborn.pydata.org/generated/seaborn.lineplot.html
# By default, the plot aggregates over multiple y values at each value of x and shows an estimate of the central tendency and a confidence interval for that estimate.
# Default estimator="mean"

# %% [markdown]
# #### **CHECANDO A DIFERENÇA (DECOMPOSIÇÃO) DE PREÇOS ENTRE ANOS**

# %%
df_viz = df.groupby(by=['ANO', 'PRODUTO'])['PREÇO MÉDIO REVENDA'].mean().unstack(level=1)
df_viz
# Out:
# PRODUTO  ETANOL HIDRATADO  GASOLINA COMUM
# ANO
# 2004             1.049059        2.047294
# 2005             1.182500        2.232900
# 2006             1.419623        2.442585
# 2007             1.272212        2.413865
# 2008             1.273769        2.402788
# 2009             1.329040        2.403000
# 2010             1.520019        2.462500
# 2011             1.865846        2.643231
# 2012             1.806623        2.636642
# 2013             1.830558        2.736404
# 2014             1.924231        2.866519
# 2015             2.104941        3.189353
# 2016             2.483442        3.499038
# 2017             2.516264        3.580245
# 2018             2.711904        4.202769
# 2019             2.717920        4.120480

# %%
plt.figure(figsize=(20, 12))
sns.lineplot(data=df_viz['ETANOL HIDRATADO'], label='ETANOL HIDRATADO')
sns.lineplot(data=df_viz['GASOLINA COMUM'], label='GASOLINA COMUM')
plt.xlim([df_viz.index.min() - 1, df_viz.index.max() + 1])
plt.ylabel('PREÇO MÉDIO REVENDA')
# Out:
# Text(0, 0.5, 'PREÇO MÉDIO REVENDA')

# %%
df_viz_diff = df_viz.diff()
df_viz_diff
# Out:
# PRODUTO  ETANOL HIDRATADO  GASOLINA COMUM
# ANO
# 2004                  NaN             NaN
# 2005             0.133441        0.185606
# 2006             0.237123        0.209685
# 2007            -0.147411       -0.028720
# 2008             0.001558       -0.011077
# 2009             0.055271        0.000212
# 2010             0.190979        0.059500
# 2011             0.345827        0.180731
# 2012            -0.059224       -0.006589
# 2013             0.023935        0.099762
# 2014             0.093673        0.130115
# 2015             0.180710        0.322834
# 2016             0.378501        0.309686
# 2017             0.032822        0.081207
# 2018             0.195640        0.622524
# 2019             0.006016       -0.082289

# %%
plt.figure(figsize=(20, 12))
sns.lineplot(data=df_viz_diff['ETANOL HIDRATADO'], label='ETANOL HIDRATADO')
sns.lineplot(data=df_viz_diff['GASOLINA COMUM'], label='GASOLINA COMUM')
plt.xlim([df_viz_diff.index.min() - 1, df_viz_diff.index.max() + 1])
plt.ylabel('PREÇO MÉDIO REVENDA')
# Out:
# Text(0, 0.5, 'PREÇO MÉDIO REVENDA')

# %%
# subplots
fig, axes = plt.subplots(2, 1, figsize=(20, 15), sharex=True)
sns.lineplot(data=df, x="ANO", y="PREÇO MÉDIO REVENDA", hue="PRODUTO", ci='sd', ax=axes[0])
axes[0].set_ylabel('PREÇO MÉDIO REVENDA')
axes[0].grid(True)

sns.lineplot(data=df_viz_diff['ETANOL HIDRATADO'], label='ETANOL HIDRATADO', ax=axes[1])
sns.lineplot(data=df_viz_diff['GASOLINA COMUM'], label='GASOLINA COMUM', ax=axes[1])
axes[1].set_ylabel('DIFERENÇA DE PREÇOS ENTRE OS ANOS MÉDIO REVENDA')
axes[1].grid(True)

plt.xlim([df_viz_diff.index.min() - 1, df_viz_diff.index.max() + 1])
# Out:
# (2003.0, 2020.0)

# %% [markdown]
# #### Boxplots

# %%
plt.figure(figsize=(20, 12))
ax = sns.boxplot(data=df, x='ANO', y='PREÇO MÉDIO REVENDA', hue='PRODUTO')
ax.set_title('Gasolina Comum x Etanol no Estado de SP entre 2004 e 2018')
ax.set_yticks(ticks_precos)

# %% [markdown]
# #### Violin Plot

# %%
plt.figure(figsize=(20, 12))
ax = sns.violinplot(data=df, x='ANO', y='PREÇO MÉDIO REVENDA', hue='PRODUTO')
ax.set_title('Gasolina Comum x Etanol no Estado de SP entre 2004 e 2018')
ax.set_yticks(ticks_precos)

# %% [markdown]
# ### 2.4 Há correlação entre os os preços da Gasolina Comum e do Etanol do estado de São Paulo de 2018?

# %%
df = data.query('ESTADO == "SAO PAULO" and PRODUTO in ["ETANOL HIDRATADO", "GASOLINA COMUM"]').reset_index(drop=True)
df
# Out:
#      DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0      2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1      2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2      2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 4      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...           ...         ...      ...        ...               ...
# 1565   2019-06-09  2019-06-15  SUDESTE  SAO PAULO    GASOLINA COMUM
# 1566   2019-06-16  2019-06-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1567   2019-06-16  2019-06-22  SUDESTE  SAO PAULO    GASOLINA COMUM
# 1568   2019-06-23  2019-06-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1569   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                             4047              R$/l                0.768
# ...

# %%
df = df[['PRODUTO', 'PREÇO MÉDIO REVENDA', 'ANO']]
df
# Out:
#                PRODUTO  PREÇO MÉDIO REVENDA   ANO
# 0     ETANOL HIDRATADO                0.768  2004
# 1     ETANOL HIDRATADO                0.766  2004
# 2     ETANOL HIDRATADO                0.823  2004
# 3     ETANOL HIDRATADO                0.887  2004
# 4     ETANOL HIDRATADO                0.894  2004
# ...                ...                  ...   ...
# 1565    GASOLINA COMUM                4.210  2019
# 1566  ETANOL HIDRATADO                2.593  2019
# 1567    GASOLINA COMUM                4.168  2019
# 1568  ETANOL HIDRATADO                2.557  2019
# 1569    GASOLINA COMUM                4.142  2019
#
# [1570 rows x 3 columns]

# %%
df_2 = df.groupby(['PRODUTO', 'ANO']).mean().unstack(level='PRODUTO')
# precos_medios = df.groupby(['PRODUTO', 'ANO']).mean()
# precos_medios  # multiindex
df_2
# Out:
#         PREÇO MÉDIO REVENDA
# PRODUTO    ETANOL HIDRATADO GASOLINA COMUM
# ANO
# 2004               1.049059       2.047294
# 2005               1.182500       2.232900
# 2006               1.419623       2.442585
# 2007               1.272212       2.413865
# 2008               1.273769       2.402788
# 2009               1.329040       2.403000
# 2010               1.520019       2.462500
# 2011               1.865846       2.643231
# 2012               1.806623       2.636642
# 2013               1.830558       2.736404
# 2014               1.924231       2.866519
# 2015               2.104941       3.189353
# 2016               2.483442       3.499038
# 2017               2.516264       3.580245
# 2018               2.711904       4.202769
# 2019               2.717920       4.120480

# %%
df_2.columns
# Out:
# MultiIndex([('PREÇO MÉDIO REVENDA', 'ETANOL HIDRATADO'),
#             ('PREÇO MÉDIO REVENDA',   'GASOLINA COMUM')],
#            names=[None, 'PRODUTO'])

# %%
sns.jointplot(x=('PREÇO MÉDIO REVENDA', 'ETANOL HIDRATADO'), y=('PREÇO MÉDIO REVENDA',   'GASOLINA COMUM'), data=df_2)

# %% [markdown]
# ### 2.5 Como os preços da Gasolina Comum e Etanol variaram no estado de SP ao longo dos anos e meses?

# %%
df = data.query('ESTADO == "SAO PAULO" and PRODUTO in ["ETANOL HIDRATADO", "GASOLINA COMUM"]').reset_index(drop=True)

# %%
df.head()
# Out:
#   DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0   2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1   2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2   2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3   2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 4   2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                          4047              R$/l                0.768
# 1                          4066              R$/l                0.766
# 2                          4077              R$/l                0.823
# 3                          4073              R$/l                0.887
# 4                          4082              R$/l                0.894
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                  0.085                 0.590                 1.150
# ...

# %%
df['ANO-MÊS'] = pd.to_datetime({'day': 1,'month': df['MÊS'],'year': df['ANO']})

# %%
df.head()
# Out:
#   DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0   2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1   2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2   2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3   2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 4   2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                          4047              R$/l                0.768
# 1                          4066              R$/l                0.766
# 2                          4077              R$/l                0.823
# 3                          4073              R$/l                0.887
# 4                          4082              R$/l                0.894
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  MARGEM MÉDIA REVENDA  \
# ...

# %%
ticks_precos = np.arange(0.0, 5.01, 0.25)

plt.figure(figsize=(30, 18))
ax = sns.lineplot(data=df, x="ANO-MÊS", y="PREÇO MÉDIO REVENDA", hue="PRODUTO", ci='sd')
ax.set_title('Gasolina Comum x Etanol no Estado de SP entre 2004 e 2018')
ax.set_yticks(ticks_precos)
plt.grid()

# %%
datas_unicas = df['ANO-MÊS'].unique()
datas_unicas
# Out:
# array(['2004-05-01T00:00:00.000000000', '2004-06-01T00:00:00.000000000',
#        '2004-07-01T00:00:00.000000000', '2004-08-01T00:00:00.000000000',
#        '2004-09-01T00:00:00.000000000', '2004-10-01T00:00:00.000000000',
#        '2004-11-01T00:00:00.000000000', '2004-12-01T00:00:00.000000000',
#        '2005-01-01T00:00:00.000000000', '2005-02-01T00:00:00.000000000',
#        '2005-03-01T00:00:00.000000000', '2005-04-01T00:00:00.000000000',
#        '2005-05-01T00:00:00.000000000', '2005-06-01T00:00:00.000000000',
#        '2005-07-01T00:00:00.000000000', '2005-08-01T00:00:00.000000000',
#        '2005-09-01T00:00:00.000000000', '2005-10-01T00:00:00.000000000',
#        '2005-11-01T00:00:00.000000000', '2005-12-01T00:00:00.000000000',
#        '2006-01-01T00:00:00.000000000', '2006-02-01T00:00:00.000000000',
#        '2006-03-01T00:00:00.000000000', '2006-04-01T00:00:00.000000000',
#        '2006-05-01T00:00:00.000000000', '2006-06-01T00:00:00.000000000',
# ...

# %%
import matplotlib.dates as mdates

ticks_precos = np.arange(0.0, 5.01, 0.25)

plt.figure(figsize=(50, 18))
ax = sns.lineplot(data=df, x="ANO-MÊS", y="PREÇO MÉDIO REVENDA", hue="PRODUTO", ci='sd')
ax.set_title('Gasolina Comum x Etanol no Estado de SP entre 2004 e 2018')
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))
ax.set_xticks(datas_unicas)
ax.set_yticks(ticks_precos)
plt.xticks(rotation=90)
plt.grid()

# %%
min_data = datas_unicas.min()
max_data = datas_unicas.max()

xticks = pd.date_range(datas_unicas.min(), datas_unicas.max(), periods=25).to_pydatetime()

# %%
import matplotlib.dates as mdates

ticks_precos = np.arange(0.0, 5.01, 0.25)

plt.figure(figsize=(30, 18))
ax = sns.lineplot(data=df, x="ANO-MÊS", y="PREÇO MÉDIO REVENDA", hue="PRODUTO", ci='sd')
ax.set_title('Gasolina Comum x Etanol no Estado de SP entre 2004 e 2018')
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))
ax.set_xticks(xticks)
ax.set_yticks(ticks_precos)
plt.grid()

# %% [markdown]
# #### Correlação entre os Preços da Gasolina e Etanol no Estado de SP

# %%
df_2 = df[['PRODUTO', 'PREÇO MÉDIO REVENDA', 'ANO-MÊS']]
df_2
# Out:
#                PRODUTO  PREÇO MÉDIO REVENDA    ANO-MÊS
# 0     ETANOL HIDRATADO                0.768 2004-05-01
# 1     ETANOL HIDRATADO                0.766 2004-05-01
# 2     ETANOL HIDRATADO                0.823 2004-05-01
# 3     ETANOL HIDRATADO                0.887 2004-05-01
# 4     ETANOL HIDRATADO                0.894 2004-06-01
# ...                ...                  ...        ...
# 1565    GASOLINA COMUM                4.210 2019-06-01
# 1566  ETANOL HIDRATADO                2.593 2019-06-01
# 1567    GASOLINA COMUM                4.168 2019-06-01
# 1568  ETANOL HIDRATADO                2.557 2019-06-01
# 1569    GASOLINA COMUM                4.142 2019-06-01
#
# [1570 rows x 3 columns]

# %%
df_2 = df_2.groupby(['PRODUTO', 'ANO-MÊS']).mean().unstack(level='PRODUTO')
df_2
# Out:
#            PREÇO MÉDIO REVENDA
# PRODUTO       ETANOL HIDRATADO GASOLINA COMUM
# ANO-MÊS
# 2004-05-01             0.81100        1.89625
# 2004-06-01             0.89875        1.98650
# 2004-07-01             0.92725        2.03000
# 2004-08-01             1.02540        2.03380
# 2004-09-01             1.03500        2.03175
# ...                        ...            ...
# 2019-02-01             2.60650        3.97400
# 2019-03-01             2.80280        4.06180
# 2019-04-01             2.87325        4.19100
# 2019-05-01             2.77675        4.27325
# 2019-06-01             2.60700        4.19300
#
# [182 rows x 2 columns]

# %%
sns.jointplot(x=('PREÇO MÉDIO REVENDA', 'ETANOL HIDRATADO'), y=('PREÇO MÉDIO REVENDA',   'GASOLINA COMUM'), data=df_2)

# %%
df_2.corr()
# Out:
#                                      PREÇO MÉDIO REVENDA
# PRODUTO                                 ETANOL HIDRATADO GASOLINA COMUM
#                     PRODUTO
# PREÇO MÉDIO REVENDA ETANOL HIDRATADO            1.000000       0.940635
#                     GASOLINA COMUM              0.940635       1.000000

# %% [markdown]
# ### 2.6 Preços dos Combustíveis por Região ao longo dos anos e meses?

# %% [markdown]
# #### UMA ALTERNATIVA

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
# juntando os meses e anos em uma data só
data['ANO-MÊS'] = pd.to_datetime({'day': 1,'month': data['MÊS'],'year': data['ANO']})

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# ...

# %%
data['PRODUTO'].unique()
# Out:
# array(['ETANOL HIDRATADO', 'GASOLINA COMUM', 'GLP', 'GNV', 'ÓLEO DIESEL',
#        'ÓLEO DIESEL S10'], dtype=object)

# %%
fig, axes = plt.subplots(3, 2, figsize=(30, 18))

sns.lineplot(data=data.query('PRODUTO == "ETANOL HIDRATADO"'), x='ANO-MÊS', y='PREÇO MÉDIO REVENDA', hue='REGIÃO', ci=None, ax=axes[0, 0])
axes[0, 0].set_title('PREÇO DO ETANOL AO LONGO DOS ANOS')

sns.lineplot(data=data.query('PRODUTO == "GASOLINA COMUM"'), x='ANO-MÊS', y='PREÇO MÉDIO REVENDA', hue='REGIÃO', ci=None, ax=axes[0, 1])
axes[0, 1].set_title('PREÇO DA GASOLINA COMUM AO LONGO DOS ANOS')

sns.lineplot(data=data.query('PRODUTO == "GNV"'), x='ANO-MÊS', y='PREÇO MÉDIO REVENDA', hue='REGIÃO', ci=None, ax=axes[1, 0])
axes[1, 0].set_title('PREÇO DO GNV COMUM AO LONGO DOS ANOS')

sns.lineplot(data=data.query('PRODUTO == "GLP"'), x='ANO-MÊS', y='PREÇO MÉDIO REVENDA', hue='REGIÃO', ci=None, ax=axes[1, 1])
axes[1, 1].set_title('PREÇO DO GLP COMUM AO LONGO DOS ANOS')

sns.lineplot(data=data.query('PRODUTO == "ÓLEO DIESEL"'), x='ANO-MÊS', y='PREÇO MÉDIO REVENDA', hue='REGIÃO', ci=None, ax=axes[2, 0])
axes[2, 0].set_title('PREÇO DO ÓLEO DIESEL COMUM AO LONGO DOS ANOS')

sns.lineplot(data=data.query('PRODUTO == "ÓLEO DIESEL S10"'), x='ANO-MÊS', y='PREÇO MÉDIO REVENDA', hue='REGIÃO', ci=None, ax=axes[2, 1])
axes[2, 1].set_title('PREÇO DO ÓLEO DIESEL S10 COMUM AO LONGO DOS ANOS')
# Out:
# Text(0.5, 1.0, 'PREÇO DO ÓLEO DIESEL S10 COMUM AO LONGO DOS ANOS')

# %% [markdown]
# No geral, a região **Norte** é a que apresenta os maiores preços de combustíveis do país.

# %% [markdown]
# #### OUTRA ALTERNATIVA

# %%
fig, axes = plt.subplots(3, 2, figsize=(30, 18))

sns.lineplot(data=data.query('REGIÃO == "NORTE"'), x='ANO-MÊS', y='PREÇO MÉDIO REVENDA', hue='PRODUTO', ci=None, ax=axes[0, 0])
axes[0, 0].set_title('PREÇO DOS COMBUSTÍVELS NA REGIÃO NORTE')

sns.lineplot(data=data.query('REGIÃO == "NORDESTE"'), x='ANO-MÊS', y='PREÇO MÉDIO REVENDA', hue='PRODUTO', ci=None, ax=axes[0, 1])
axes[0, 1].set_title('PREÇO DOS COMBUSTÍVELS NA REGIÃO NORDESTE')

sns.lineplot(data=data.query('REGIÃO == "CENTRO OESTE"'), x='ANO-MÊS', y='PREÇO MÉDIO REVENDA', hue='PRODUTO', ci=None, ax=axes[1, 0])
axes[1, 0].set_title('PREÇO DOS COMBUSTÍVELS NA REGIÃO CENTRO-OESTE')

sns.lineplot(data=data.query('REGIÃO == "SUDESTE"'), x='ANO-MÊS', y='PREÇO MÉDIO REVENDA', hue='PRODUTO', ci=None, ax=axes[1, 1])
axes[1, 1].set_title('PREÇO DOS COMBUSTÍVELS NA REGIÃO SUDESTE')

sns.lineplot(data=data.query('REGIÃO == "SUL"'), x='ANO-MÊS', y='PREÇO MÉDIO REVENDA', hue='PRODUTO', ci=None, ax=axes[2, 0])
axes[2, 0].set_title('PREÇO DOS COMBUSTÍVELS NA REGIÃO SUL')
# Out:
# Text(0.5, 1.0, 'PREÇO DOS COMBUSTÍVELS NA REGIÃO SUL')

# %% [markdown]
# Como o preço do GLP é muito discrepante do preço dos outros combustíveis, nossa análise fica totalmente prejudicada. <br/>
# Podemos ignorar o GLP neste momento e comparar os preços entre os outros combustíveis.

# %%
df = data.query('PRODUTO != "GLP"')

# %%
fig, axes = plt.subplots(3, 2, figsize=(30, 18))

sns.lineplot(data=df.query('REGIÃO == "NORTE"'), x='ANO-MÊS', y='PREÇO MÉDIO REVENDA', hue='PRODUTO', ci=None, ax=axes[0, 0])
axes[0, 0].set_title('PREÇO DOS COMBUSTÍVELS NA REGIÃO NORTE')

sns.lineplot(data=df.query('REGIÃO == "NORDESTE"'), x='ANO-MÊS', y='PREÇO MÉDIO REVENDA', hue='PRODUTO', ci=None, ax=axes[0, 1])
axes[0, 1].set_title('PREÇO DOS COMBUSTÍVELS NA REGIÃO NORDESTE')

sns.lineplot(data=df.query('REGIÃO == "CENTRO OESTE"'), x='ANO-MÊS', y='PREÇO MÉDIO REVENDA', hue='PRODUTO', ci=None, ax=axes[1, 0])
axes[1, 0].set_title('PREÇO DOS COMBUSTÍVELS NA REGIÃO CENTRO-OESTE')

sns.lineplot(data=df.query('REGIÃO == "SUDESTE"'), x='ANO-MÊS', y='PREÇO MÉDIO REVENDA', hue='PRODUTO', ci=None, ax=axes[1, 1])
axes[1, 1].set_title('PREÇO DOS COMBUSTÍVELS NA REGIÃO SUDESTE')

sns.lineplot(data=df.query('REGIÃO == "SUL"'), x='ANO-MÊS', y='PREÇO MÉDIO REVENDA', hue='PRODUTO', ci=None, ax=axes[2, 0])
axes[2, 0].set_title('PREÇO DOS COMBUSTÍVELS NA REGIÃO SUL')
# Out:
# Text(0.5, 1.0, 'PREÇO DOS COMBUSTÍVELS NA REGIÃO SUL')

# %% [markdown]
# ### 2.7 Comportamento dos Preços dos Combustíveis dos Estados do Norte?

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# ...

# %%
data_norte = data.query('REGIÃO == "NORTE"')
data_norte.head()
# Out:
#    DATA INICIAL  DATA FINAL REGIÃO    ESTADO           PRODUTO  \
# 13   2004-05-09  2004-05-15  NORTE      ACRE  ETANOL HIDRATADO
# 14   2004-05-09  2004-05-15  NORTE     AMAPA  ETANOL HIDRATADO
# 15   2004-05-09  2004-05-15  NORTE  AMAZONAS  ETANOL HIDRATADO
# 16   2004-05-09  2004-05-15  NORTE      PARA  ETANOL HIDRATADO
# 17   2004-05-09  2004-05-15  NORTE  RONDONIA  ETANOL HIDRATADO
#
#     NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 13                            33              R$/l                1.805
# 14                            15              R$/l                1.785
# 15                            53              R$/l                1.578
# 16                           104              R$/l                1.914
# 17                            97              R$/l                1.545
#
#     DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  MARGEM MÉDIA REVENDA  \
# ...

# %%
fig, axes = plt.subplots(2, 1, sharex=True, figsize=(30, 18))

sns.barplot(data=data_norte.query('PRODUTO == "GASOLINA COMUM"'), x='ESTADO', y='PREÇO MÉDIO REVENDA', ci='sd', ax=axes[0])
axes[0].set_title('PREÇO DA GASOLINA COMUM NOS ESTADOS DO NORTE')

sns.barplot(data=data_norte.query('PRODUTO == "ETANOL HIDRATADO"'), x='ESTADO', y='PREÇO MÉDIO REVENDA', ci='sd', ax=axes[1])
axes[0].set_title('PREÇO DO ETANOL NOS ESTADOS DO NORTE')
# Out:
# Text(0.5, 1.0, 'PREÇO DO ETANOL NOS ESTADOS DO NORTE')

# %% [markdown]
# Na média, o estado do **ACRE** apresentou **os preços mais caros** para a _Gasolina Comum_ e _Etanol_ considerando os anos de 2004 a 2018

# %% [markdown]
# ##### **ANALISANDO OS PREÇOS ANO A ANO**

# %%
fig, axes = plt.subplots(2, 1, sharex=True, figsize=(30, 18))

sns.barplot(data=data_norte.query('PRODUTO == "GASOLINA COMUM"'), x='ANO', y='PREÇO MÉDIO REVENDA', hue='ESTADO', ci='sd', ax=axes[0])
axes[0].set_title('PREÇO DA GASOLINA COMUM NOS ESTADOS DO NORTE')

sns.barplot(data=data_norte.query('PRODUTO == "ETANOL HIDRATADO"'), x='ANO', y='PREÇO MÉDIO REVENDA', hue='ESTADO', ci='sd', ax=axes[1])
axes[0].set_title('PREÇO DO ETANOL NOS ESTADOS DO NORTE')
# Out:
# Text(0.5, 1.0, 'PREÇO DO ETANOL NOS ESTADOS DO NORTE')

# %%
data_norte_gasol_etan = data_norte.query('PRODUTO in ["GASOLINA COMUM", "ETANOL HIDRATADO"]')
data_norte_gasol_etan
# Out:
#        DATA INICIAL  DATA FINAL REGIÃO     ESTADO           PRODUTO  \
# 13       2004-05-09  2004-05-15  NORTE       ACRE  ETANOL HIDRATADO
# 14       2004-05-09  2004-05-15  NORTE      AMAPA  ETANOL HIDRATADO
# 15       2004-05-09  2004-05-15  NORTE   AMAZONAS  ETANOL HIDRATADO
# 16       2004-05-09  2004-05-15  NORTE       PARA  ETANOL HIDRATADO
# 17       2004-05-09  2004-05-15  NORTE   RONDONIA  ETANOL HIDRATADO
# ...             ...         ...    ...        ...               ...
# 103329   2019-06-23  2019-06-29  NORTE   AMAZONAS    GASOLINA COMUM
# 103339   2019-06-23  2019-06-29  NORTE       PARA    GASOLINA COMUM
# 103347   2019-06-23  2019-06-29  NORTE   RONDONIA    GASOLINA COMUM
# 103348   2019-06-23  2019-06-29  NORTE    RORAIMA    GASOLINA COMUM
# 103352   2019-06-23  2019-06-29  NORTE  TOCANTINS    GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
df_norte_gasol_etan = data_norte_gasol_etan.groupby(['ANO', 'PRODUTO', 'ESTADO']).mean().reset_index()
df_norte_gasol_etan
# Out:
#       ANO           PRODUTO     ESTADO  NÚMERO DE POSTOS PESQUISADOS  \
# 0    2004  ETANOL HIDRATADO       ACRE                     33.294118
# 1    2004  ETANOL HIDRATADO      AMAPA                     12.382353
# 2    2004  ETANOL HIDRATADO   AMAZONAS                     57.500000
# 3    2004  ETANOL HIDRATADO       PARA                    107.058824
# 4    2004  ETANOL HIDRATADO   RONDONIA                     95.882353
# ..    ...               ...        ...                           ...
# 218  2019    GASOLINA COMUM   AMAZONAS                     72.720000
# 219  2019    GASOLINA COMUM       PARA                    115.080000
# 220  2019    GASOLINA COMUM   RONDONIA                     71.080000
# 221  2019    GASOLINA COMUM    RORAIMA                     13.000000
# 222  2019    GASOLINA COMUM  TOCANTINS                     45.960000
#
#      PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# ...

# %%
fig, axes = plt.subplots(2, 1, figsize=(30, 18))

sns.barplot(data=df_norte_gasol_etan.query('PRODUTO == "GASOLINA COMUM"'), x='ANO', y='PREÇO MÉDIO REVENDA', hue='ESTADO', ci='sd', ax=axes[0])
axes[0].set_title('PREÇO DA GASOLINA COMUM NOS ESTADOS DO NORTE')

sns.barplot(data=df_norte_gasol_etan.query('PRODUTO == "ETANOL HIDRATADO"'), x='ANO', y='PREÇO MÉDIO REVENDA', hue='ESTADO', ci='sd', ax=axes[1])
axes[0].set_title('PREÇO DO ETANOL NOS ESTADOS DO NORTE')
# Out:
# Text(0.5, 1.0, 'PREÇO DO ETANOL NOS ESTADOS DO NORTE')

# %% [markdown]
# ### 2.8 Há correlação entre os Preços de Distribuição e o Preço de Revenda dos combustíveis?

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# ...

# %%
df = data[["PREÇO MÉDIO REVENDA", "PREÇO MÉDIO DISTRIBUIÇÃO"]]
df.head()
# Out:
#    PREÇO MÉDIO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO
# 0                1.288                     0.825
# 1                1.162                     0.763
# 2                1.389                     0.970
# 3                1.262                     0.830
# 4                1.181                     0.941

# %%
df.corr()
# Out:
#                           PREÇO MÉDIO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO
# PREÇO MÉDIO REVENDA                  1.000000                  0.994852
# PREÇO MÉDIO DISTRIBUIÇÃO             0.994852                  1.000000

# %%
sns.lmplot(data=df, x="PREÇO MÉDIO REVENDA", y="PREÇO MÉDIO DISTRIBUIÇÃO", aspect=5, height=10)

# %%
plt.figure(figsize=(30, 18))
sns.regplot(data=df, x="PREÇO MÉDIO REVENDA", y="PREÇO MÉDIO DISTRIBUIÇÃO")
# Out:
# <AxesSubplot:xlabel='PREÇO MÉDIO REVENDA', ylabel='PREÇO MÉDIO DISTRIBUIÇÃO'>

# %%
sns.jointplot(data=df, x="PREÇO MÉDIO REVENDA", y="PREÇO MÉDIO DISTRIBUIÇÃO", kind='hex', height=10)

# %%
# Análisando apenas o intervalor mais denso
df_viz = df[df['PREÇO MÉDIO REVENDA'] <= 10]

sns.jointplot(data=df_viz, x="PREÇO MÉDIO REVENDA", y="PREÇO MÉDIO DISTRIBUIÇÃO", kind='hex', height=10)
